# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from pprint import pprint
from config import api_key

# %%
state_renew = requests.get(f'http://api.eia.gov/category/?api_key={api_key}&category_id=40425').json()
series_id = []
state_renew_info = []
df_list = []
childseries = state_renew['category']['childseries']
for state in range(len(childseries)):
    series = childseries[state]["series_id"]
    series_id.append(series)
for series in series_id:
    state_info = requests.get(f'http://api.eia.gov/series/?api_key={api_key}&series_id={series}').json()
    state_renew_info.append(state_info)
for i in range(len(state_renew_info)):
    name = state_renew_info[i]['series'][0]['geography']
    name = pd.DataFrame(state_renew_info[i]['series'][0]['data'][0])
    df_list.append(name)
    
pprint (state_renew_info)
# Out:
# [{'request': {'command': 'series', 'series_id': 'SEDS.RETCB.AK.A'},
#   'series': [{'copyright': 'None',
#               'data': [['2016', 19428],
#                        ['2015', 19209],
#                        ['2014', 19826],
#                        ['2013', 18664],
#                        ['2012', 17719],
#                        ['2011', 15762],
#                        ['2010', 16537],
#                        ['2009', 15685],
#                        ['2008', 12913],
#                        ['2007', 14037],
#                        ['2006', 13298],
#                        ['2005', 15866],
#                        ['2004', 18857],
#                        ['2003', 19598],
#                        ['2002', 18257],
#                        ['2001', 17439],
#                        ['2000', 12375],
#                        ['1999', 10605],
#                        ['1998', 13638],
#                        ['1997', 15583],
#                        ['1996', 21915],
# ...

# %%
df_list = []
state_list = [
'Alaska',
'Alabama',
'Arkansas' ,
'Arizona',
'California', 
'Colorado' ,
'Connecticut', 
'District of Columbia',
'Delaware' ,
'Florida' ,
'Georgia' ,
'Hawaii' ,
'Iowa',
'Idaho' ,
'Illinois' ,
'Indiana' ,
'Kansas', 
'Kentucky', 
'Louisiana' ,
'Massachusetts',
'Maryland' ,
'Maine',
'Michigan' ,
'Minnesota' ,
'Missouri',
'Mississippi', 
'Montana' ,
'North Carolina' ,
'North Dakota' ,
'Nebraska', 
'New Hampshire', 
'New Jersey' ,
'New Mexico' ,
'Nevada' ,
'New York' ,
'Ohio' ,
'Oklahoma', 
'Oregon' ,
'Pennsylvania' ,
'Rhode Island' ,
'South Carolina', 
'South Dakota' ,
'Tennessee' ,
'Texas' ,
'United States',
'Utah' ,
'Virginia' ,
'Vermont', 
'Washington', 
'Wisconsin' ,
'West Virginia' ,
'Wyoming',
]
k=0
for i in range(len(state_renew_info)):
    name = state_renew_info[i]['series'][0]['name']
    dataframe = pd.DataFrame(state_renew_info[i]['series'][0]['data'])
    df_list.append({name: dataframe})
    
    
# pprint (df_list)    
years_df = pd.DataFrame(df_list[0][f'Renewable energy total consumption, Alaska'][0])
pprint(df_list)
# Out:
# [{'Renewable energy total consumption, Alaska':        0      1
# 0   2016  19428
# 1   2015  19209
# 2   2014  19826
# 3   2013  18664
# 4   2012  17719
# 5   2011  15762
# 6   2010  16537
# 7   2009  15685
# 8   2008  12913
# 9   2007  14037
# 10  2006  13298
# 11  2005  15866
# 12  2004  18857
# 13  2003  19598
# 14  2002  18257
# 15  2001  17439
# 16  2000  12375
# 17  1999  10605
# 18  1998  13638
# 19  1997  15583
# 20  1996  21915
# 21  1995  23142
# 22  1994  23590
# 23  1993  20551
# 24  1992  18300
# 25  1991  17357
# 26  1990  18357
# 27  1989  18342
# 28  1988  12761
# 29  1987  12004
# 30  1986  10707
# 31  1985  11783
# 32  1984  11152
# 33  1983   9591
# 34  1982   8745
# 35  1981   9216
# 36  1980   8321
# 37  1979  10733
# 38  1978  10809
# 39  1977  11449
# 40  1976   9201
# 41  1975   8608
# 42  1974   8329
# 43  1973   7844
# 44  1972   8673
# 45  1971   9094
# 46  1970   8835
# 47  1969   8455
# 48  1968   8486
# 49  1967   8457
# 50  1966   8328
# ...

# %%
count = 0
for state in state_list:
    years_df[f'{state_list[count]}'] = df_list[count][f'Renewable energy total consumption, {state}'][1]
    count +=1

years_df.drop(columns=['District of Columbia'])
years_df.rename(columns = {0:'Year'})
# Out:
#     Year  Alaska  Alabama  Arkansas  Arizona  California  Colorado  \
# 0   2016   19428   256090    125096   158237     1046744    152282
# 1   2015   19209   284450    128400   147467      859490    128347
# 2   2014   19826   290746    128947   138125      857583    130235
# 3   2013   18664   332489    128612   119104      852365    121819
# 4   2012   17719   263095    122947   114598      806824    106448
# 5   2011   15762   276863    131836   128112      940168    105341
# 6   2010   16537   264186    136161   100410      829172     79881
# 7   2009   15685   273619    130201    95856      725204     78223
# 8   2008   12913   237119    125658   111600      679899     77268
# 9   2007   14037   228635    121020    97235      706866     50496
# 10  2006   13298   266305    100080    95418      897179     42139
# 11  2005   15866   279765    112547    92172      819329     35522
# 12  2004   18857   293216    112915    82440      768877     29092
# ...

# %%
years_df.to_csv('Outputs/renewable_energy_consumption.csv')
