# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from pprint import pprint
from config import api_key

# %%
state_coal = requests.get(f'http://api.eia.gov/category/?api_key={api_key}&category_id=40478').json()
series_id = []
state_coal_info = []
df_list = []
childseries = state_coal['category']['childseries']
for state in range(len(childseries)):
    series = childseries[state]["series_id"]
    series_id.append(series)
for series in series_id:
    state_info = requests.get(f'http://api.eia.gov/series/?api_key={api_key}&series_id={series}').json()
    state_coal_info.append(state_info)
for i in range(len(state_coal_info)):
    name = state_coal_info[i]['series'][0]['geography']
    name = pd.DataFrame(state_coal_info[i]['series'][0]['data'][0])
    df_list.append(name)
    
pprint (state_coal_info)
# Out:
# [{'request': {'command': 'series', 'series_id': 'SEDS.CLTCB.AK.A'},
#   'series': [{'copyright': 'None',
#               'data': [['2016', 16613],
#                        ['2015', 19511],
#                        ['2014', 18225],
#                        ['2013', 14819],
#                        ['2012', 15521],
#                        ['2011', 15481],
#                        ['2010', 14548],
#                        ['2009', 14505],
#                        ['2008', 14705],
#                        ['2007', 13662],
#                        ['2006', 14981],
#                        ['2005', 13994],
#                        ['2004', 14075],
#                        ['2003', 12552],
#                        ['2002', 16429],
#                        ['2001', 15911],
#                        ['2000', 16455],
#                        ['1999', 16394],
#                        ['1998', 16471],
#                        ['1997', 11719],
#                        ['1996', 11152],
# ...

# %%
df_list = []
state_list = [
'Alaska',
'Alabama',
'Arkansas' ,
'Arizona',
'California', 
'Colorado' ,
'Connecticut', 
'District of Columbia',
'Delaware' ,
'Florida' ,
'Georgia' ,
'Hawaii' ,
'Iowa',
'Idaho' ,
'Illinois' ,
'Indiana' ,
'Kansas', 
'Kentucky', 
'Louisiana' ,
'Massachusetts',
'Maryland' ,
'Maine',
'Michigan' ,
'Minnesota' ,
'Missouri',
'Mississippi', 
'Montana' ,
'North Carolina' ,
'North Dakota' ,
'Nebraska', 
'New Hampshire', 
'New Jersey' ,
'New Mexico' ,
'Nevada' ,
'New York' ,
'Ohio' ,
'Oklahoma', 
'Oregon' ,
'Pennsylvania' ,
'Rhode Island' ,
'South Carolina', 
'South Dakota' ,
'Tennessee' ,
'Texas' ,
'United States',
'Utah' ,
'Virginia' ,
'Vermont', 
'Washington', 
'Wisconsin' ,
'West Virginia' ,
'Wyoming',
]
k=0
for i in range(len(state_coal_info)):
    name = state_coal_info[i]['series'][0]['name']
    dataframe = pd.DataFrame(state_coal_info[i]['series'][0]['data'])
    df_list.append({name: dataframe})
    
    
# pprint (df_list)    
years_df = pd.DataFrame(df_list[0][f'Coal total consumption, Alaska'][0])
pprint(df_list)
# Out:
# [{'Coal total consumption, Alaska':        0      1
# 0   2016  16613
# 1   2015  19511
# 2   2014  18225
# 3   2013  14819
# 4   2012  15521
# 5   2011  15481
# 6   2010  14548
# 7   2009  14505
# 8   2008  14705
# 9   2007  13662
# 10  2006  14981
# 11  2005  13994
# 12  2004  14075
# 13  2003  12552
# 14  2002  16429
# 15  2001  15911
# 16  2000  16455
# 17  1999  16394
# 18  1998  16471
# 19  1997  11719
# 20  1996  11152
# 21  1995  12882
# 22  1994  12578
# 23  1993  13630
# 24  1992  12509
# 25  1991  12675
# 26  1990  12387
# 27  1989   4719
# 28  1988   4362
# 29  1987   4330
# 30  1986  12150
# 31  1985  11587
# 32  1984  12883
# 33  1983  12403
# 34  1982  13182
# 35  1981  12521
# 36  1980   4310
# 37  1979   4182
# 38  1978   4689
# 39  1977  10259
# 40  1976  13706
# 41  1975  15271
# 42  1974  12485
# 43  1973  13286
# 44  1972  12753
# 45  1971  14121
# 46  1970  13159
# 47  1969  13191
# 48  1968  15998
# 49  1967  18462
# 50  1966  16431
# 51  1965   9888
# ...

# %%
count = 0
for state in state_list:
    years_df[f'{state_list[count]}'] = df_list[count][f'Coal total consumption, {state}'][1]
    count +=1

years_df.drop(columns=['District of Columbia'])
years_df.rename(columns = {0:'Year'})
# Out:
#     Year  Alaska  Alabama  Arkansas  Arizona  California  Colorado  \
# 0   2016   16613   410168    246437   323878       32077    321476
# 1   2015   19511   494311    226889   385822       30967    340107
# 2   2014   18225   575912    339214   447849       39486    350526
# 3   2013   14819   565051    327099   454865       38151    363532
# 4   2012   15521   547004    296732   420570       43832    370085
# 5   2011   15481   651032    306119   459909       55264    368871
# 6   2010   14548   718684    293689   457909       54972    382623
# 7   2009   14505   630969    264083   413260       52403    350224
# 8   2008   14705   842826    278849   458727       63050    385416
# 9   2007   13662   888436    275037   438524       66495    388586
# 10  2006   14981   886678    256907   431985       67017    394348
# 11  2005   13994   890098    247169   428445       67422    386670
# 12  2004   14075   853917    270210   425413       68909    390186
# ...

# %%
years_df.to_csv('Outputs/coal_consumption.csv')
