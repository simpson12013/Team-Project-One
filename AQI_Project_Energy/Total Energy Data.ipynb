# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from pprint import pprint
from config import api_key

# %%
state_total = requests.get(f'http://api.eia.gov/category/?api_key={api_key}&category_id=40236').json()
series_id = []
state_total_info = []
df_list = []
childseries = state_total['category']['childseries']
for state in range(len(childseries)):
    series = childseries[state]["series_id"]
    series_id.append(series)
for series in series_id:
    state_info = requests.get(f'http://api.eia.gov/series/?api_key={api_key}&series_id={series}').json()
    state_total_info.append(state_info)
for i in range(len(state_total_info)):
    name = state_total_info[i]['series'][0]['geography']
    name = pd.DataFrame(state_total_info[i]['series'][0]['data'][0])
    df_list.append(name)
    
pprint (state_total_info)
# Out:
# [{'request': {'command': 'series', 'series_id': 'SEDS.TETCB.AK.A'},
#   'series': [{'copyright': 'None',
#               'data': [['2016', 599964],
#                        ['2015', 617872],
#                        ['2014', 604917],
#                        ['2013', 617921],
#                        ['2012', 650535],
#                        ['2011', 654999],
#                        ['2010', 654595],
#                        ['2009', 639694],
#                        ['2008', 650420],
#                        ['2007', 723069],
#                        ['2006', 746316],
#                        ['2005', 797700],
#                        ['2004', 775038],
#                        ['2003', 733500],
#                        ['2002', 732973],
#                        ['2001', 735820],
#                        ['2000', 742138],
#                        ['1999', 725402],
#                        ['1998', 723309],
#                        ['1997', 708823],
# ...

# %%
df_list = []
state_list = [
'Alaska',
'Alabama',
'Arkansas' ,
'Arizona',
'California', 
'Colorado' ,
'Connecticut', 
'District of Columbia',
'Delaware' ,
'Florida' ,
'Georgia' ,
'Hawaii' ,
'Iowa',
'Idaho' ,
'Illinois' ,
'Indiana' ,
'Kansas', 
'Kentucky', 
'Louisiana' ,
'Massachusetts',
'Maryland' ,
'Maine',
'Michigan' ,
'Minnesota' ,
'Missouri',
'Mississippi', 
'Montana' ,
'North Carolina' ,
'North Dakota' ,
'Nebraska', 
'New Hampshire', 
'New Jersey' ,
'New Mexico' ,
'Nevada' ,
'New York' ,
'Ohio' ,
'Oklahoma', 
'Oregon' ,
'Pennsylvania' ,
'Rhode Island' ,
'South Carolina', 
'South Dakota' ,
'Tennessee' ,
'Texas' ,
'United States',
'Utah' ,
'Virginia' ,
'Vermont', 
'Washington', 
'Wisconsin' ,
'West Virginia' ,
'Wyoming',
]
k=0
for i in range(len(state_total_info)):
    name = state_total_info[i]['series'][0]['name']
    dataframe = pd.DataFrame(state_total_info[i]['series'][0]['data'])
    df_list.append({name: dataframe})
    
    
# pprint (df_list)    
years_df = pd.DataFrame(df_list[0][f'Total energy consumption, Alaska'][0])
pprint(df_list)
# Out:
# [{'Total energy consumption, Alaska':        0       1
# 0   2016  599964
# 1   2015  617872
# 2   2014  604917
# 3   2013  617921
# 4   2012  650535
# 5   2011  654999
# 6   2010  654595
# 7   2009  639694
# 8   2008  650420
# 9   2007  723069
# 10  2006  746316
# 11  2005  797700
# 12  2004  775038
# 13  2003  733500
# 14  2002  732973
# 15  2001  735820
# 16  2000  742138
# 17  1999  725402
# 18  1998  723309
# 19  1997  708823
# 20  1996  718796
# 21  1995  704170
# 22  1994  623159
# 23  1993  623702
# 24  1992  627237
# 25  1991  602660
# 26  1990  584083
# 27  1989  576194
# 28  1988  521404
# 29  1987  499218
# 30  1986  504260
# 31  1985  474439
# 32  1984  482898
# 33  1983  437637
# 34  1982  409072
# 35  1981  279672
# 36  1980  295757
# 37  1979  299782
# 38  1978  324057
# 39  1977  293532
# 40  1976  254674
# 41  1975  232186
# 42  1974  201495
# 43  1973  196970
# 44  1972  214384
# 45  1971  200968
# 46  1970  182043
# 47  1969  156633
# 48  1968  122532
# ...

# %%
count = 0
for state in state_list:
    years_df[f'{state_list[count]}'] = df_list[count][f'Total energy consumption, {state}'][1]
    count +=1

years_df.drop(columns=['District of Columbia'])
years_df.rename(columns = {0:'Year'})
# Out:
#     Year  Alaska  Alabama  Arkansas  Arizona  California  Colorado  \
# 0   2016  599964  1933554   1056497  1470610     7830294   1484567
# 1   2015  617872  1928506   1064733  1441373     7689270   1486406
# 2   2014  604917  1970506   1122070  1420738     7588165   1482814
# 3   2013  617921  1933911   1104819  1412152     7641507   1468544
# 4   2012  650535  1889769   1072259  1394235     7549428   1440947
# 5   2011  654999  1915974   1127856  1424258     7766158   1471398
# 6   2010  654595  1941374   1125436  1384168     7757919   1514026
# 7   2009  639694  1800938   1042171  1380865     7779429   1466090
# 8   2008  650420  2003763   1110485  1466685     8083096   1488589
# 9   2007  723069  2086251   1128824  1498670     8265016   1484714
# 10  2006  746316  2102503   1114862  1471611     8291763   1432717
# 11  2005  797700  2064982   1118725  1425934     8168407   1416083
# 12  2004  775038  2083465   1095431  1384853     8262592   1382203
# ...

# %%
years_df.to_csv('Outputs/total_energy_consumption.csv')
