# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from pprint import pprint
from config import api_key

# %%
state_wind = requests.get(f'http://api.eia.gov/category/?api_key={api_key}&category_id=40324').json()
series_id = []
state_wind_info = []
df_list = []
childseries = state_wind['category']['childseries']
for state in range(len(childseries)):
    series = childseries[state]["series_id"]
    series_id.append(series)
for series in series_id:
    state_info = requests.get(f'http://api.eia.gov/series/?api_key={api_key}&series_id={series}').json()
    state_wind_info.append(state_info)
for i in range(len(state_wind_info)):
    name = state_wind_info[i]['series'][0]['geography']
    name = pd.DataFrame(state_wind_info[i]['series'][0]['data'][0])
    df_list.append(name)
    
pprint (state_wind_info)
# Out:
# [{'request': {'command': 'series', 'series_id': 'SEDS.WYTCB.AK.A'},
#   'series': [{'copyright': 'None',
#               'data': [['2016', 1563],
#                        ['2015', 1488],
#                        ['2014', 1445],
#                        ['2013', 1386],
#                        ['2012', 356],
#                        ['2011', 121],
#                        ['2010', 123],
#                        ['2009', 69],
#                        ['2008', 1],
#                        ['2007', 10],
#                        ['2006', 8],
#                        ['2005', 6],
#                        ['2004', 0],
#                        ['2003', 0],
#                        ['2002', 0],
#                        ['2001', 10],
#                        ['2000', 0],
#                        ['1999', 0],
#                        ['1998', 0],
#                        ['1997', 0],
#                        ['1996', 0],
#                        ['1995', 0],
# ...

# %%
df_list = []
state_list = [
'Alaska',
'Alabama',
'Arkansas' ,
'Arizona',
'California', 
'Colorado' ,
'Connecticut', 
'District of Columbia',
'Delaware' ,
'Florida' ,
'Georgia' ,
'Hawaii' ,
'Iowa',
'Idaho' ,
'Illinois' ,
'Indiana' ,
'Kansas', 
'Kentucky', 
'Louisiana' ,
'Massachusetts',
'Maryland' ,
'Maine',
'Michigan' ,
'Minnesota' ,
'Missouri',
'Mississippi', 
'Montana' ,
'North Carolina' ,
'North Dakota' ,
'Nebraska', 
'New Hampshire', 
'New Jersey' ,
'New Mexico' ,
'Nevada' ,
'New York' ,
'Ohio' ,
'Oklahoma', 
'Oregon' ,
'Pennsylvania' ,
'Rhode Island' ,
'South Carolina', 
'South Dakota' ,
'Tennessee' ,
'Texas' ,
'United States',
'Utah' ,
'Virginia' ,
'Vermont', 
'Washington', 
'Wisconsin' ,
'West Virginia' ,
'Wyoming',
]
k=0
for i in range(len(state_wind_info)):
    name = state_wind_info[i]['series'][0]['name']
    dataframe = pd.DataFrame(state_wind_info[i]['series'][0]['data'])
    df_list.append({name: dataframe})
    
    
# pprint (df_list)    
years_df = pd.DataFrame(df_list[0][f'Wind energy, total consumed, Alaska'][0])
pprint(df_list)
# Out:
# [{'Wind energy, total consumed, Alaska':        0     1
# 0   2016  1563
# 1   2015  1488
# 2   2014  1445
# 3   2013  1386
# 4   2012   356
# 5   2011   121
# 6   2010   123
# 7   2009    69
# 8   2008     1
# 9   2007    10
# 10  2006     8
# 11  2005     6
# 12  2004     0
# 13  2003     0
# 14  2002     0
# 15  2001    10
# 16  2000     0
# 17  1999     0
# 18  1998     0
# 19  1997     0
# 20  1996     0
# 21  1995     0
# 22  1994     0
# 23  1993     0
# 24  1992     0
# 25  1991     0
# 26  1990     0
# 27  1989     0
# 28  1988     0
# 29  1987     0
# 30  1986     0
# 31  1985     0
# 32  1984     0
# 33  1983     0
# 34  1982     0
# 35  1981     0
# 36  1980     0
# 37  1979     0
# 38  1978     0
# 39  1977     0
# 40  1976     0
# 41  1975     0
# 42  1974     0
# 43  1973     0
# 44  1972     0
# 45  1971     0
# 46  1970     0
# 47  1969     0
# 48  1968     0
# 49  1967     0
# 50  1966     0
# 51  1965     0
# 52  1964     0
# 53  1963     0
# 54  1962     0
# ...

# %%
count = 0
for state in state_list:
    years_df[f'{state_list[count]}'] = df_list[count][f'Wind energy, total consumed, {state}'][1]
    count +=1

years_df.drop(columns=['District of Columbia'])
years_df.rename(columns = {0:'Year'})
# Out:
#     Year  Alaska  Alabama  Arkansas  Arizona  California  Colorado  \
# 0   2016    1563        0         0     5000      124715     86977
# 1   2015    1488        0         0     4213      113967     69662
# 2   2014    1445        0         0     4452      123559     70076
# 3   2013    1386        0         0     4291      122335     68731
# 4   2012     356        0         0     5059       92821     56798
# 5   2011     121        0         0     2483       75317     50526
# 6   2010     123        0         0     1316       59303     33676
# 7   2009      69        0         0      288       56997     30879
# 8   2008       1        0         0        0       53063     31738
# 9   2007      10        0         0        0       55201     12765
# 10  2006       8        0         0        0       48433      8585
# 11  2005       6        0         0        0       42618      7762
# 12  2004       0        0         0        0       43128      2205
# ...

# %%
years_df.to_csv('Outputs/wind_energy_consumption.csv')
