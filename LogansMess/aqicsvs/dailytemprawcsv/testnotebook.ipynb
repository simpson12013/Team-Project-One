# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
file = pd.read_csv("daily_TEMP_1985.csv")
filedf = pd.DataFrame(file)
countynames = filedf["County Name"].unique()
datedf = filedf["Date Local"].str.split("-",expand = True)
datedf.columns = ["Year","Month","Day"]
filedf["Month"] = datedf["Month"]
filedf["Year"] = datedf["Year"]
filedf["Day"] = datedf["Day"]
filedf["State Name"].unique()
filedf
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0               4            1         7           62101    1  34.128103
# 1               4            1         7           62101    1  34.128103
# 2               4            1         7           62101    1  34.128103
# 3               4            1         7           62101    1  34.128103
# 4               4            1         7           62101    1  34.128103
# 5               4            1         7           62101    1  34.128103
# 6               4            1         7           62101    1  34.128103
# 7               4            1         7           62101    1  34.128103
# 8               4            1         7           62101    1  34.128103
# 9               4            1         7           62101    1  34.128103
# 10              4            1         7           62101    1  34.128103
# 11              4            1         7           62101    1  34.128103
# ...

# %%
file2df = filedf.groupby(["County Name","Month"])
countydatedf = file2df.mean().unstack(level = 1)
countydf = countydatedf["Arithmetic Mean"]
state_df = pd.DataFrame(countydf)
# state_df["Latitude"] = filedf["Latitude"]
state_df.dropna
latitude = []
longitude = []
i = 0
for county in countynames:
    if filedf["County Name"][i] not in county:
        latitude.append(filedf["Latitude"][i])
        longitude.append(filedf["Longitude"][i])
        
        i += 1

# %%
year = 1980
county_data = []
while year <= 2017:
    file = pd.read_csv(f"daily_TEMP_{year}.csv")
    filedf = pd.DataFrame(file)    
    datedf = filedf["Date Local"].str.split("-",expand = True)
    datedf.columns = ["Year","Month","Day"]
    filedf["Year"] = datedf["Year"]
    filedf["Month"] = datedf["Month"]
    filedf["Day"] = datedf["Day"]
    file2df = filedf.groupby(["State Name", "Month"])
    countydatedf = file2df.mean().unstack(level = 1)
    countydf = countydatedf["Arithmetic Mean"]
    countydf.to_csv(f"temp_month_state_{year}.csv")
    
    year += 1
# Out:
# /Users/loganmiller/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Out:
#   File "<ipython-input-57-f5b67e66969e>", line 1
#     del countynames(-1)
#        ^
# SyntaxError: can't delete function call

# %%
state_df["Latitude"] = latitude
state_df["Longitude"] = longitude
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-ff92819304ea> in <module>()
# ----> 1 state_df["Latitude"] = latitude
#       2 state_df["Longitude"] = longitude
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3386
# ...

# %%
# finaldf = state_df[state_df.Latitude != "whoops"]
final2df = state_df[state_df.Latitude > 25]
final3df = final2df[final2df.Longitude < -40]
final4df = final3df[final3df.Longitude > -140]
final5df = final4df[final4df.Latitude < 50]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-7927a37e0266> in <module>()
#       1 # finaldf = state_df[state_df.Latitude != "whoops"]
# ----> 2 final2df = state_df[state_df.Latitude > 25]
#       3 final3df = final2df[final2df.Longitude < -40]
#       4 final4df = final3df[final3df.Longitude > -140]
#       5 final5df = final4df[final4df.Latitude < 50]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Latitude'

# %%
statedf.to_csv("aqi_state_yearly.csv")
